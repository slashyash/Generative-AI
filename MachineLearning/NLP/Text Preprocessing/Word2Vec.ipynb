# %%
import gensim
from gensim.models import Word2Vec, KeyedVectors

# %%
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')

# %%
vectorforking=wv['king']

# %%
vectorforking
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
wv.most_similar('king')
# Out:
# [('kings', 0.7138046622276306),
#  ('queen', 0.6510956287384033),
#  ('monarch', 0.6413194537162781),
#  ('crown_prince', 0.6204219460487366),
#  ('prince', 0.6159993410110474),
#  ('sultan', 0.5864824056625366),
#  ('ruler', 0.5797566771507263),
#  ('princes', 0.5646552443504333),
#  ('Prince_Paras', 0.5432944297790527),
#  ('throne', 0.5422105193138123)]

# %%
wv.most_similar('dell')
# Out:
# [('asus', 0.5947496891021729),
#  ('samsung', 0.5789060592651367),
#  ('sony', 0.5707899928092957),
#  ('acer', 0.5621021389961243),
#  ('imac', 0.5565451383590698),
#  ('xps', 0.5464506149291992),
#  ('ibm', 0.542077362537384),
#  ('cpu', 0.5304328799247742),
#  ('schede', 0.5300740599632263),
#  ('lcd', 0.5278486013412476)]

# %%
wv.similarity('dell', 'asus')
# Out:
# 0.5947497

# %%
wv.similarity('samsung', 'apple')
# Out:
# 0.2928738

# %%
vec = wv['laptop']- wv['keyboard'] + wv['touchscreen']

# %%
vec
# Out:
# array([ 0.15344238,  0.12451172,  0.2366333 ,  0.46069336,  0.04199219,
#         0.05664062, -0.09716797, -0.10864258,  0.09234619, -0.02294922,
#        -0.1652832 , -0.22460938, -0.29296875,  0.06152344, -0.13305664,
#         0.10449219,  0.10620117,  0.08691406,  0.01531982,  0.17578125,
#         0.1307373 , -0.01782227,  0.24865723, -0.17468262,  0.26586914,
#         0.14941406, -0.10400391,  0.35083008,  0.62402344, -0.42670345,
#         0.16235352,  0.13494873, -0.06152344, -0.26049805, -0.2593689 ,
#        -0.453125  , -0.4873047 , -0.39672852, -0.28222656,  0.0847168 ,
#         0.10742188,  0.16552734, -0.11410522, -0.01269531, -0.12719727,
#         0.0118103 , -0.02026367,  0.21374512,  0.04589844,  0.2163086 ,
#        -0.01074219,  0.125     ,  0.28710938, -0.01351929, -0.20559692,
#        -0.30456543,  0.01218414, -0.11193848,  0.2454834 , -0.10327148,
#         0.07421875, -0.04217529, -0.19238281,  0.19750977, -0.07885742,
# ...

# %%
wv.most_similar([vec])
# Out:
# [('touchscreen', 0.6781651973724365),
#  ('laptop', 0.6683094501495361),
#  ('laptops', 0.6366260647773743),
#  ('touch_screen', 0.6152582764625549),
#  ('touchscreens', 0.5907723307609558),
#  ('netbook', 0.5832337141036987),
#  ('tablet_PC', 0.5745983719825745),
#  ('smartphone', 0.5605534315109253),
#  ('Acer_netbook', 0.553318440914154),
#  ('ultraportable_laptop', 0.5429997444152832)]

# %%
vec1 = wv['king']- wv['man'] + wv['woman']

# %%
wv.most_similar(vec1)
# Out:
# [('king', 0.8449392318725586),
#  ('queen', 0.7300516366958618),
#  ('monarch', 0.6454660296440125),
#  ('princess', 0.6156251430511475),
#  ('crown_prince', 0.5818676948547363),
#  ('prince', 0.5777117609977722),
#  ('kings', 0.5613663792610168),
#  ('sultan', 0.5376776456832886),
#  ('Queen_Consort', 0.5344247817993164),
#  ('queens', 0.5289887189865112)]
